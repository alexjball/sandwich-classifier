# %% [markdown]
# # Load a Pre-Trained Model and Test Cases

# %%
from fastai.vision import *

# %%
classifier_dir = 'model'
hot_dog = 'data/hot-dog.jpeg'
tacos = 'data/tacos.jpeg'

# %%
hot_dog_img = open_image(hot_dog)
tacos_img = open_image(tacos)

# %%
model = load_learner(classifier_dir)

# %% [markdown]
# # Classify a Hot Dog

# %%
pred_class.data.__dict__
# Out:
# {}

# %%
pred_class,pred_idx,outputs = model.predict(hot_dog_img)

display(pred_class)
display(hot_dog_img)
# Out:
# Category hot_dogs
# Image (3, 186, 271)

# %% [markdown]
# # Classify Tacos

# %%
pred_class,pred_idx,outputs = model.predict(tacos_img)

display(pred_class)
display(tacos_img)
# Out:
# Category tacos
# Image (3, 194, 259)
